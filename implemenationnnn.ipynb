# %%
import os
import cv2
from imutils import paths
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import models,layers
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from tensorflow import keras

# %%
datapath=r"C:\Users\User\Downloads\gest_folder"

# %%
#labels =set(['A','B','C'])
pathToImage =list(paths.list_images(datapath))
print(pathToImage)
data =[]
labels =[]
for images in pathToImage:
    label=images.split(os.path.sep)[-2]
    #print(label)
    image =cv2.imread(images)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    data.append(image)
    labels.append(label)
    #plt.figure()
# Out:
# ['C:\\Users\\User\\Downloads\\gest_folder\\A\\0.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\1.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\10.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\11.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\12.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\13.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\14.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\15.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\16.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\17.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\18.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\19.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\2.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\20.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\21.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\22.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\23.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\24.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\25.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\26.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\27.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\28.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\29.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\3.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\30.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\31.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\32.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\33.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\34.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\35.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\36.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\37.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\38.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\39.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\4.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\40.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\41.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\42.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\43.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\44.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\45.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\46.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\47.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\48.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\49.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\5.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\6.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\7.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\8.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\A\\9.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\0.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\1.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\10.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\11.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\12.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\13.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\14.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\15.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\16.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\17.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\18.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\19.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\2.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\20.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\21.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\22.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\23.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\24.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\25.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\26.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\27.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\28.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\29.jpg', 'C:\\Users\\User\\Downloads\\gest_folder\\B\\3.jpg', 'C:\\Users\\User\ ...

# %%
# Total number of images and labels
print('Total number of images',len(data))
print('Total number of labels',len(set(labels)))
print("Labels:",[X for X in set(labels)])
# Out:
# Total number of images 150
# Total number of labels 3
# Labels: ['C', 'A', 'B']

# %%
for i in range(8):
    plt.subplot(2,4,i+1)
    plt.imshow(data[i])
    plt.title(labels[i])

# %%
blur_img=[]
hsv_img=[]
for img in data:
    Gaussian_blur=cv2.GaussianBlur(img,(5,5),0)
    Hsv_img=cv2.cvtColor(Gaussian_blur,cv2.COLOR_BGR2HSV)
    blur_img.append(Gaussian_blur)
    hsv_img.append(Hsv_img)

# %%
#Gaussian blur image 
for i in range(8):
    plt.subplot(2,4,i+1)
    plt.imshow(data[i])
    plt.title(labels[i])

# %%
#HSV image
for i in range(8):
    plt.subplot(2,4,i+1)
    #plt.imshow(blur_img[i]) 
    plt.imshow(hsv_img[i])
    plt.title(labels[i])

# %%
img_HSV=cv2.cvtColor(blur_img[i],cv2.COLOR_BGR2HSV)#img_HSV=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
cv2.imshow("HSV Image",img_HSV)
cv2.imshow("HSV Channel",img_HSV[:,:,0])
cv2.imshow("HSV Saturation",img_HSV[:,:,1])
cv2.imshow("HSV Value",img_HSV[:,:,2])

#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
lower_green=(25,40,50)
upper_green=(75,255,255)
mask=cv2.inRange(img_HSV,lower_green,upper_green)
kernel=get.StructuringElement(cv2.MORPH_ELLIPSE(11,11))
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

bMask = mask > 0
clear = np.zeros_like(img, np.uint8)  # Create empty image
clear[bMask] = img[bMask]  # Apply boolean mask to the origin image
clear_TrainImg.append(clear)

# %%
x_train,x_test,y_train,y_test = train_test_split(data,labels,test_size =0.2,stratify =labels,random_state =42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)

# %%
x_test.shape[0]

# %%
lb = preprocessing.LabelBinarizer()
y_train =lb.fit_transform(y_train)
y_test =lb.fit_transform(y_test)

# %%
x_test.shape,y_test.shape

# %%
#CNN
# 1st sequential for forward and backoard propogation
model = models.Sequential()
#adding convolution layer
model.add(layers.Conv2D(16, (3, 3), activation='relu', input_shape=(224, 224, 3),padding ='same'))
#max pooling
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu',padding ='same'))
model.add(layers.MaxPooling2D((2, 2)))
# Drop_out
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(64, (3, 3), activation='relu',padding ='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(128, (3, 3), activation='relu',padding ='same'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))

# %%
# now flatten 
model.add(layers.Flatten())
# fully connected neural network
model.add(layers.Dense(256, activation='relu'))
#model.add(layers.Dense(200,activation='relu'))
model.add(layers.Dense(3,activation='softmax'))

# %%
model.summary()

# %%
x_train.shape,y_train.shape

# %%
x_test.shape,y_test.shape

# %%
# complie and train model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs = 20, validation_split=0.2)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
#plt.ylim([0.5, 1])
plt.legend(loc='lower right')

#test_loss, test_acc = model.evaluate(validation_ds, verbose=2)

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('val_loss')
#plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
'''# keras tuner
def build_model(hp):  
  model = keras.Sequential([
    keras.layers.Conv2D(
        filters=hp.Int('conv_1_filter', min_value=32, max_value=128, step=16),
        kernel_size=hp.Choice('conv_1_kernel', values = [3,5]),
        activation='relu',
        input_shape=(224,224,3)
    ),
    keras.layers.Conv2D(
        filters=hp.Int('conv_2_filter', min_value=32, max_value=64, step=16),
        kernel_size=hp.Choice('conv_2_kernel', values = [3,5]),
        activation='relu'
    ),
    keras.layers.Flatten(),
    keras.layers.Dense(
        units=hp.Int('dense_1_units', min_value=32, max_value=128, step=16),
        activation='relu'
    ),
    keras.layers.Dense(10, activation='softmax')
  ])
  
  model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-2, 1e-3])),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
  
  return model'''

# %%
'''from keras_tuner import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters'''

# %%
'''tuner_search=RandomSearch(build_model,
                          objective='val_accuracy',
                          max_trials=5,directory='output',project_name="sign_language")'''

# %%
'''tuner_search.search(x_train,train_label,epochs=3,validation_split=0.1)'''

# %%
x_test.shape

# %%
y_test.shape

# %%
score = model.evaluate(x_test, y_test,batch_size=32)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# PLOTTING CONFUSION MATRIX

# %%
y_predict=model.predict(x_test)
print(y_predict)
y_result  =np.argmax(y_predict,axis =1)
print(y_result)
y_test=np.argmax(y_test,axis =1)

# %%
print(y_result)

# %%
plt.imshow(x_test[2])

# %%
import seaborn as sns
from sklearn.metrics import classification_report as cr,accuracy_score,confusion_matrix
cm =confusion_matrix(y_test,y_result)
sns.heatmap(cm,annot =True)
print("accuracy_score",accuracy_score(y_test,y_result))
print()
print('confusion_matrix',cr(y_test,y_result))

# %%
y_test

# %%
path_a=r'C:\Users\User\Downloads\home samples\A\13.jpg'

# %%
import cv2 
img_1 =cv2.imread(path_a)
print(img_1)
img_2= cv2.cvtColor(img_1,cv2.COLOR_BGR2RGB)
img_2=cv2.resize(img_2,(224,224))
img_2 =img_2/225
new_image = tf.expand_dims(img_2,0)
print(img_2)
print(new_image)
plt.imshow(img_2)

# %%
pred_img=model.predict(np.array(new_image))
print(pred_img)
pred_result  =np.argmax(pred_img,axis =1)
pred_result

# %% [markdown]
# path_b =r'C:\Users\User\Downloads\home samples\B\44.jpg'
# img_b =cv2.imread(path_b)
# print(img_b)
# plt.imshow(img_b)
# img_B= cv2.cvtColor(img_b,cv2.COLOR_BGR2RGB)
# img_B=cv2.resize(img_B,(224,224))
# img_B =img_B/225
# new_image_b= tf.expand_dims(img_B,0)
# print(img_B)
# print(new_image)
# plt.imshow(img_B)

# %% [markdown]
# pred_img=model.predict(np.array(new_image_b))
# print(pred_img)
# pred_result  =np.argmax(pred_img,axis =1)
# pred_result

# %% [markdown]
# path_c =r'C:\Users\User\Downloads\home samples\C\44.jpg'
# img_c =cv2.imread(path_c)
# print(img_c)
# plt.imshow(img_c)
# img_C= cv2.cvtColor(img_c,cv2.COLOR_BGR2RGB)
# img_C=cv2.resize(img_C,(224,224))
# img_C =img_C/225
# new_image_c= tf.expand_dims(img_C,0)
# print(img_C)
# print(new_image_c)
# plt.imshow(img_C)

# %% [markdown]
# pred_img=model.predict(np.array(new_image))
# print(pred_img)
# pred_result  =np.argmax(pred_img,axis =1)
# pred_result

# %% [markdown]
# from keras.models import load_model
# import cv2
# import numpy as np
#
# model = load_model(r'C:\Users\User\Downloads\B\12.jpg')
#
# model.compile(loss='binary_crossentropy',
#               optimizer='rmsprop',
#               metrics=['accuracy'])
#
# img = cv2.imread('path_b.jpg')
# img = cv2.resize(img,(320,240))
# img = np.reshape(img,[1,320,240,3])
#
# classes = model.predict_classes(img)
#
# print(classes)
